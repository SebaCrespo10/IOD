# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/players.csv')

# %%
df.head(5)
# Out:
#   Nacionalidad  Número de Camiseta                    Nombre  ID del jugador
# 0    Venezuela                 1.0            Elvis Perrozzi       452748788  \
# 1        Suiza                 2.0                Bob Krause       454459828
# 2      Bélgica                 4.0          Widmar Dombrecht       440691736
# 3    Argentina                 5.0  Pablo César Del Castillo       454474072
# 4    Argentina                 6.0            Amadeo Nicora        454409328
#
#    Entrenador Especialidad  Bonus para el club madre  Lesiones
# 0         NaN          NaN                       NaN       NaN  \
# 1         NaN       Rápido                       NaN       NaN
# 2         NaN          NaN                       NaN       2.0
# 3         NaN   Cabeceador                       1.0       NaN
# 4         NaN      Técnico                       1.0       NaN
#
#    Amonestaciones  En la lista de transferencias  ...  Arquero  Defensa
# ...

# %%
df.columns = ['pais', 'numero', 'nombre', 'id',
       'entrenador', 'especialidad', 'bonus', 'lesiones',
       'amonestaciones', 'transferible', 'edad', 'dias',
       'tsi', 'sueldo', 'antiguedad', 'experiencia', 'liderazgo',
       'lealtad', 'forma', 'condición', 'arquero', 'defensa', 'jugadas',
       'lateral', 'asistencias', 'anotación', 'pelota_parada',
       'ultimo_partido', 'calificacion_ultimo_partido',
       'posicion_ultimo_partido']

# %%
df.dtypes
# Out:
# pais                            object
# numero                         float64
# nombre                          object
# id                               int64
# entrenador                     float64
# especialidad                    object
# bonus                          float64
# lesiones                       float64
# amonestaciones                 float64
# transferible                   float64
# edad                             int64
# dias                             int64
# tsi                              int64
# sueldo                           int64
# antiguedad                       int64
# experiencia                      int64
# liderazgo                        int64
# lealtad                          int64
# forma                            int64
# condición                        int64
# arquero                          int64
# defensa                          int64
# jugadas                          int64
# lateral                          int64
# ...

# %%
df.numero.count()
# Out:
# 14

# %%
df_titulares = df[df.numero.isnull() == False]

# %%
df_titulares2 = df_titulares.drop(['entrenador'], axis=1)

# %%
df_titulares2.head(3)
# Out:
#         pais  numero            nombre         id especialidad  bonus
# 0  Venezuela     1.0    Elvis Perrozzi  452748788          NaN    NaN  \
# 1      Suiza     2.0        Bob Krause  454459828       Rápido    NaN
# 2    Bélgica     4.0  Widmar Dombrecht  440691736          NaN    NaN
#
#    lesiones  amonestaciones  transferible  edad  ...  arquero  defensa
# 0       NaN             NaN           NaN    27  ...       11       10  \
# 1       NaN             NaN           NaN    26  ...        1       15
# 2       2.0             1.0           NaN    32  ...        1       14
#
#    jugadas  lateral  asistencias  anotación  pelota_parada  ultimo_partido
# 0        2        2            1          4             16      15-06-2023  \
# 1        6        3           11          3              2      11-06-2023
# 2        6        2            6          4              5      15-06-2023
#
#    calificacion_ultimo_partido  posicion_ultimo_partido
# ...
